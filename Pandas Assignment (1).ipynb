# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',  
'londON_StockhOlm', 
'Budapest_PaRis', 'Brussels_londOn'], 
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085], 
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]], 
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )', 
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df.iloc[1,1] = 10055.0
df.iloc[3,1] = 10075.0

# %%
df['FlightNumber'] = df['FlightNumber'].astype(dtype = 'int64')

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
List1 = []
List2 = []
for x in df['From_To'].str.split('_'):
    List1.append(x[0])
    List2.append(x[1])

# %%
df1 = pd.DataFrame(List1,columns = ['From'])
df2 = pd.DataFrame(List2,columns = ['To'])

# %%
df1
# Out:
#        From
# 0    LoNDon
# 1    MAdrid
# 2    londON
# 3  Budapest
# 4  Brussels

# %%
df2
# Out:
#           To
# 0      paris
# 1      miLAN
# 2  StockhOlm
# 3      PaRis
# 4     londOn

# %%
#df.drop('From_To',axis = 1,inplace = True)

# %%
df = pd.concat([df,df1,df2],axis = 1)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df['From'] = df['From'].str.lower()
df['To'] = df['To'].str.lower()

# %%
df['From'] = df['From'].str.capitalize()
df['To'] = df['To'].str.capitalize()

# %%
df.drop('From_To', axis = 1, inplace = True)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055            []    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['RecentDelays'] = df['RecentDelays'].apply(lambda x : [np.nan] if len(x) == 0 else x)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline      From         To
# 0         10045      [23, 47]               KLM(!)    London      Paris
# 1         10055         [nan]    <Air France> (12)    Madrid      Milan
# 2         10065  [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075          [13]       12. Air France  Budapest      Paris
# 4         10085      [67, 32]          "Swiss Air"  Brussels     London

# %%
df['RecentDelays'][0].append(np.nan)
df['RecentDelays'][1].append(np.nan)
df['RecentDelays'][3].append(np.nan)
#df['RecentDelays'][4].append(np.nan)

# %%
df
# Out:
#    FlightNumber     RecentDelays              Airline      From         To
# 0         10045    [23, 47, nan]               KLM(!)    London      Paris
# 1         10055  [nan, nan, nan]    <Air France> (12)    Madrid      Milan
# 2         10065     [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075   [13, nan, nan]       12. Air France  Budapest      Paris
# 4         10085    [67, 32, nan]          "Swiss Air"  Brussels     London

# %%
List1 = []
List2 = []
List3 = []
for x in df['RecentDelays']:
    List1.append(x[0])
    List2.append(x[1])
    List3.append(x[2])

# %%
df1 = pd.DataFrame(List1, columns = ['delay_1'])
df2 = pd.DataFrame(List2, columns = ['delay_2'])
df3 = pd.DataFrame(List3, columns = ['delay_3'])

# %%
df = pd.concat([df,df1,df2,df3], axis = 1)

# %%
df
# Out:
#    FlightNumber     RecentDelays              Airline      From         To  \
# 0         10045    [23, 47, nan]               KLM(!)    London      Paris
# 1         10055  [nan, nan, nan]    <Air France> (12)    Madrid      Milan
# 2         10065     [24, 43, 87]  (British Airways. )    London  Stockholm
# 3         10075   [13, nan, nan]       12. Air France  Budapest      Paris
# 4         10085    [67, 32, nan]          "Swiss Air"  Brussels     London
#
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df['Delays'] = df[['RecentDelays']]

# %%
df.drop('RecentDelays',axis = 1, inplace = True)

# %%
df
# Out:
#    FlightNumber              Airline      From         To  delay_1  delay_2  \
# 0         10045               KLM(!)    London      Paris     23.0     47.0
# 1         10055    <Air France> (12)    Madrid      Milan      NaN      NaN
# 2         10065  (British Airways. )    London  Stockholm     24.0     43.0
# 3         10075       12. Air France  Budapest      Paris     13.0      NaN
# 4         10085          "Swiss Air"  Brussels     London     67.0     32.0
#
#    delay_3           Delays
# 0      NaN    [23, 47, nan]
# 1      NaN  [nan, nan, nan]
# 2     87.0     [24, 43, 87]
# 3      NaN   [13, nan, nan]
# 4      NaN    [67, 32, nan]
